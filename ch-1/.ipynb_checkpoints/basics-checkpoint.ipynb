# %% [markdown]
# Basic LLM Calls

# %%
from openai import OpenAI
import os


client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_KEY")
)

response = client.chat.completions.create(
    model="nvidia/nemotron-nano-9b-v2:free",
    messages=[
        {"role": "user", "content": "Who is the president of the United States?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# As of October2023, the president of the United States is **Joe Biden**. He assumed office on January 20, 2021, and is a member of the Democratic Party. His vice president is **Kamala Harris**.
