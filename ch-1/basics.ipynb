# %% [markdown]
# Basic LLM Calls

# %%
from openai import OpenAI
import os


client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_KEY")
)

response = client.chat.completions.create(
    model="nvidia/nemotron-nano-9b-v2:free",
    messages=[
        {"role": "user", "content": "tell me a fun fact?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Absolutely! Here's afun fact: **Octopuses have three hearts!** Two of them pump blood to the gills, while the third sends blood to the rest of the body. Even cooler? The heart that serves the body actually *stops beating* when the octopus swims, which is why they often prefer crawling—it’s less tiring! 🐙

# %% [markdown]
# Using LangChain

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_KEY"),
    model="nvidia/nemotron-nano-9b-v2:free",
    temperature=0
)

llm_openai.invoke("tell me a fun fact?").content
# Out:
# '\n\nSure! 🐙 Did you know that octopuses have three hearts? Two of them pump blood to the gills, while the third sends blood to the rest of the body. Even cooler: the heart that serves the body actually *stops beating* when the octopus swims, which is why they often prefer crawling—it’s less tiring! 😄\n'
